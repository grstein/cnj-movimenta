# %%
import json
import gc
import os
#importação de bibliotecas

import numpy as np
import pandas as pd
from glob import glob
from pandas import json_normalize #package for flattening json in pandas df

# %matplotlib inline

# %% [markdown]
# ## Carregar as tabelas necessárias

# %%
df_assuntos = pd.read_csv('./base/estadual_1116/assuntos.csv',sep=',').set_index('dadosBasicos.numero')
df_basicos = pd.read_csv('./base/estadual_1116/dados_basicos.csv',sep=',').set_index('dadosBasicos.numero')
df_movimentos = pd.read_csv('./base/estadual_1116/movimentos.csv',sep=',').set_index('dadosBasicos.numero')
df_sgt_mov = pd.read_csv('./base/sgt_movimentos.csv',sep=';').set_index('codigo')
df_serventias
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,1,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,1,3,4,10,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-a6ce804372ec> in <module>
# ...

# %%
df_movimentos
# Out:
#                      identificadorMovimento  tipoResponsavelMovimento  \
# dadosBasicos.numero
# 50006423320208130620                      1                       0.0
# 50006423320208130620                      2                       0.0
# 50006423320208130620                      3                       0.0
# 50006423320208130620                      4                       1.0
# 50006423320208130620                      5                       0.0
# ...                                     ...                       ...
# 194177520108190068                      NaN                       NaN
# 191691220108190068                      NaN                       0.0
# 191691220108190068                      NaN                       NaN
# 193345920108190068                      NaN                       0.0
# 193345920108190068                      NaN                       NaN
#
#                                                     complementoNacional  \
# dadosBasicos.numero
# ...

# %% [markdown]
# ## Ajustar tipos de dado

# %%
df_assuntos.describe()

# %% [markdown]
# ## Verificar um exemplo

# %%
#df_processo = df_basicos.sample(1).join(df_assuntos).dropna(axis=1).join(df_movimentos).dropna(axis=1)
df_basicos.sample(1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 00000514020108130287 to 00000514020108130287
# Data columns (total 17 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   millisInsercao                                  1 non-null      int64
#  1   siglaTribunal                                   1 non-null      object
#  2   grau                                            1 non-null      object
#  3   dadosBasicos.valorCausa                         1 non-null      float64
#  4   dadosBasicos.procEl                             1 non-null      float64
#  5   dadosBasicos.competencia                        1 non-null      float64
#  6   dadosBasicos.codigoLocalidade                   1 non-null      int64
#  7   dadosBasicos.dscSistema                         1 non-null      float64
#  8   dadosBasicos.tamanhoProcesso                    1 non-null      float64
# ...

# %%
tst = df_basicos.sample(1).join(df_assuntos).join(df_movimentos)
tst
#df_processo.info()['dataHora'] = pd.to_datetime(df_processo['dataHora'])
# Out:
#                       millisInsercao siglaTribunal grau  \
# dadosBasicos.numero
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# ...                              ...           ...  ...
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
# 00048221920108130107   1597079415208          TJMG   G1
#
#                       dadosBasicos.valorCausa  dadosBasicos.procEl  \
# dadosBasicos.numero
# 00048221920108130107                  8877.05                  2.0
# 00048221920108130107                  8877.05                  2.0
# ...

# %%
df_processo
# Out:
#                       millisInsercao siglaTribunal grau  \
# dadosBasicos.numero
# 00022799320108130349   1597163697799          TJMG   G1
#
#                       dadosBasicos.valorCausa  dadosBasicos.procEl  \
# dadosBasicos.numero
# 00022799320108130349                 169188.1                  2.0
#
#                       dadosBasicos.competencia  dadosBasicos.codigoLocalidade  \
# dadosBasicos.numero
# 00022799320108130349                       7.0                            349
#
#                       dadosBasicos.dscSistema  dadosBasicos.tamanhoProcesso  \
# dadosBasicos.numero
# 00022799320108130349                      8.0                           0.0
#
#                       dadosBasicos.dataAjuizamento  \
# dadosBasicos.numero
# 00022799320108130349                20100202140956
#
#                       dadosBasicos.totalAssuntos  dadosBasicos.nivelSigilo  \
# dadosBasicos.numero
# 00022799320108130349                         2.0                         0
#
# ...
