# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style='whitegrid')

# %% [markdown]
# # Movimentações Processuais
# O arquivo sgt_movimentos.csv contém uma estrutura simplificada da tabela de movimentos processuais disponível no SGT em:
# https://www.cnj.jus.br/sgt/consulta_publica_movimentos.php.
# Atributos:
# - **codigo**: código identificador único da Movimentação Processual.
# - **descricao**: descrição da Movimentação Processual;
# - **cod_pai**: código identificador da Movimentação Processual pai;
# - **cod_filhos**: lista com os códigos dos movimentos processuais filhos daquele movimento;

# %%
sgt_movimentos = pd.read_csv('base/sgt_movimentos.csv', sep=';')
sgt_movimentos['codigo'] = sgt_movimentos['codigo'].astype(float)
sgt_movimentos.set_index('codigo', inplace=True)
sgt_movimentos.head()
# Out:
#            descricao  cod_pai  \
# codigo
# 1.0       Magistrado      NaN
# 3.0          Decisão      1.0
# 7.0        Conversão      3.0
# 11.0      Declaração      3.0
# 14.0    Serventuário      NaN
#
#                                                cod_filhos
# codigo
# 1.0     3,193,11009,7,11,25,56,63,83,108,113,117,122,1...
# 3.0     7,11,25,56,63,83,108,113,117,122,133,138,146,1...
# 7.0                                   266,821,12140,12473
# 11.0                             269,941,1003,12150,12151
# 14.0    15,18,48,104,865,12522,16,979,980,478,479,480,...

# %% [markdown]
# # Dados Justiça Eleitoral, Classe Execução Fiscal (número 1116)

# %% [markdown]
# ## dados básicos

# %%
df_base = pd.read_csv('base/estadual_1116/dados_basicos.csv', index_col=0)
df_base['dadosBasicos.dataAjuizamento'] = pd.to_datetime(df_base['dadosBasicos.dataAjuizamento'],
                                                         format='%Y%m%d%H%M%S', errors='coerce')
print(df_base.shape)
df_base.head()
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (46998, 17)
#                       millisInsercao siglaTribunal grau  \
# dadosBasicos.numero
# 50006423320208130620   1596842405951          TJMG   G1
# 50006431820208130620   1596839821655          TJMG   G1
# 50006440320208130620   1596840618466          TJMG   G1
# 50006458520208130620   1596839978166          TJMG   G1
# 50006467020208130620   1596839983462          TJMG   G1
#
#                       dadosBasicos.valorCausa  dadosBasicos.procEl  \
# dadosBasicos.numero
# 50006423320208130620                  2157.81                  1.0
# 50006431820208130620                   751.18                  1.0
# 50006440320208130620                   719.03                  1.0
# 50006458520208130620                  1321.80                  1.0
# 50006467020208130620                  1071.21                  1.0
#
#                       dadosBasicos.competencia  dadosBasicos.codigoLocalidade  \
# dadosBasicos.numero
# 50006423320208130620                       8.0                            620
# 50006431820208130620                       8.0                            620
# 50006440320208130620                       8.0                            620
# 50006458520208130620                       8.0                            620
# 50006467020208130620                       8.0                            620
#
#                       dadosBasicos.dscSistema  dadosBasicos.tamanhoProcesso  \
# dadosBasicos.numero
# 50006423320208130620                      8.0                           0.0
# 50006431820208130620                      8.0                           0.0
# 50006440320208130620                      8.0                           0.0
# 50006458520208130620                      8.0                           0.0
# 50006467020208130620                      8.0                           0.0
#
#                      dadosBasicos.dataAjuizamento  dadosBasicos.totalAssuntos  \
# dadosBasicos.numero
# 50006423320208130620          2020-03-18 06:06:29                         1.0
# 50006431820208130620          2020-03-18 06:11:46                         1.0
# 50006440320208130620          2020-03-18 06:16:33                         1.0
# 50006458520208130620          2020-03-18 06:21:42                         1.0
# 50006467020208130620          2020-03-18 06:32:59                         1.0
#
#                       dadosBasicos.nivelSigilo  dadosBasicos.classeProcessual  \
# dadosBasicos.numero
# 50006423320208130620                         0                           1116
# 50006431820208130620                         0                           1116
# 50006440320208130620                         0                           1116
# 50006458520208130620                         0                           1116
# 50006467020208130620                         0                           1116
#
#                                    dadosBasicos.orgaoJulgador.nomeOrgao  \
# dadosBasicos.numero
# 50006423320208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006431820208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006440320208130620  1ª Vara Cível, Criminal e de Execuções Penais ...
# 50006458520208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006467020208130620  1ª Vara Cível, Criminal e de Execuções Penais ...
#
#                       dadosBasicos.orgaoJulgador.codigoMunicipioIBGE  \
# dadosBasicos.numero
# 50006423320208130620                                         3162005
# 50006431820208130620                                         3162005
# 50006440320208130620                                         3162005
# 50006458520208130620                                         3162005
# 50006467020208130620                                         3162005
#
#                       dadosBasicos.orgaoJulgador.codigoOrgao  \
# dadosBasicos.numero
# 50006423320208130620                                    5843
# 50006431820208130620                                    5843
# 50006440320208130620                                    5836
# 50006458520208130620                                    5843
# 50006467020208130620                                    5836
#
#                      dadosBasicos.orgaoJulgador.instancia
# dadosBasicos.numero
# 50006423320208130620                                 ORIG
# 50006431820208130620                                 ORIG
# 50006440320208130620                                 ORIG
# 50006458520208130620                                 ORIG
# 50006467020208130620                                 ORIG

# %% [markdown]
# ## movimentos

# %%
df_moves = pd.read_csv('base/estadual_1116/movimentos.csv', index_col=0)
df_moves['dataHora'] = pd.to_datetime(df_moves['dataHora'], format='%Y%m%d%H%M%S')
print(df_moves.shape)
df_moves.head()
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,1,3,4,10,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (1720223, 18)
#                      identificadorMovimento  tipoResponsavelMovimento  \
# dadosBasicos.numero
# 50006423320208130620                      1                       0.0
# 50006423320208130620                      2                       0.0
# 50006423320208130620                      3                       0.0
# 50006423320208130620                      4                       1.0
# 50006423320208130620                      5                       0.0
#
#                                                     complementoNacional  \
# dadosBasicos.numero
# 50006423320208130620  [{'descricaoComplemento': 'tipo_de_distribuica...
# 50006423320208130620  [{'descricaoComplemento': 'tipo_de_documento',...
# 50006423320208130620  [{'descricaoComplemento': 'tipo_de_conclusao',...
# 50006423320208130620                                                 []
# 50006423320208130620  [{'descricaoComplemento': 'tipo_de_documento',...
#
#                      idDocumentoVinculado  movimentoLocal  nivelSigilo  \
# dadosBasicos.numero
# 50006423320208130620                   []             NaN          0.0
# 50006423320208130620                   []             NaN          0.0
# 50006423320208130620                   []             NaN          0.0
# 50006423320208130620                   []             NaN          0.0
# 50006423320208130620                   []             NaN          0.0
#
#                                 dataHora  tipoDecisao  \
# dadosBasicos.numero
# 50006423320208130620 2020-03-18 06:06:30          NaN
# 50006423320208130620 2020-03-19 14:54:37          NaN
# 50006423320208130620 2020-03-19 14:55:01          NaN
# 50006423320208130620 2020-03-24 14:17:33          NaN
# 50006423320208130620 2020-06-10 11:09:43          NaN
#
#                       movimentoNacional.codigoNacional  \
# dadosBasicos.numero
# 50006423320208130620                              26.0
# 50006423320208130620                              60.0
# 50006423320208130620                              51.0
# 50006423320208130620                           11010.0
# 50006423320208130620                              60.0
#
#                                                 orgaoJulgador.nomeOrgao  \
# dadosBasicos.numero
# 50006423320208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006423320208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006423320208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006423320208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
# 50006423320208130620  2ª Vara Cível, Criminal e da Infância e da Juv...
#
#                       orgaoJulgador.codigoMunicipioIBGE  \
# dadosBasicos.numero
# 50006423320208130620                          3162005.0
# 50006423320208130620                          3162005.0
# 50006423320208130620                          3162005.0
# 50006423320208130620                          3162005.0
# 50006423320208130620                          3162005.0
#
#                       orgaoJulgador.codigoOrgao orgaoJulgador.instancia  \
# dadosBasicos.numero
# 50006423320208130620                     5843.0                    ORIG
# 50006423320208130620                     5843.0                    ORIG
# 50006423320208130620                     5843.0                    ORIG
# 50006423320208130620                     5843.0                    ORIG
# 50006423320208130620                     5843.0                    ORIG
#
#                       movimentoNacional  orgaoJulgador  \
# dadosBasicos.numero
# 50006423320208130620                NaN            NaN
# 50006423320208130620                NaN            NaN
# 50006423320208130620                NaN            NaN
# 50006423320208130620                NaN            NaN
# 50006423320208130620                NaN            NaN
#
#                       movimentoLocal.movimentoLocalPai  \
# dadosBasicos.numero
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
#
#                       movimentoLocal.codigoMovimento  \
# dadosBasicos.numero
# 50006423320208130620                             NaN
# 50006423320208130620                             NaN
# 50006423320208130620                             NaN
# 50006423320208130620                             NaN
# 50006423320208130620                             NaN
#
#                       movimentoLocal.codigoPaiNacional
# dadosBasicos.numero
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN
# 50006423320208130620                               NaN

# %% [markdown]
# ## assuntos

# %%
df_assuntos = pd.read_csv('base/estadual_1116/assuntos.csv', index_col=0)
print(df_assuntos.shape)
df_assuntos.head()
# Out:
# (77517, 9)
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,1,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                      principal  assuntoLocal  codigoNacional  \
# dadosBasicos.numero
# 50006423320208130620      True           NaN          5952.0
# 50006423320208130620      True           NaN          5952.0
# 50006431820208130620      True           NaN          5952.0
# 50006431820208130620      True           NaN          5952.0
# 50006440320208130620      True           NaN          5952.0
#
#                       assuntoLocal.codigoAssunto  \
# dadosBasicos.numero
# 50006423320208130620                         NaN
# 50006423320208130620                         NaN
# 50006431820208130620                         NaN
# 50006431820208130620                         NaN
# 50006440320208130620                         NaN
#
#                       assuntoLocal.codigoPaiNacional assuntoLocal.descricao  \
# dadosBasicos.numero
# 50006423320208130620                             NaN                    NaN
# 50006423320208130620                             NaN                    NaN
# 50006431820208130620                             NaN                    NaN
# 50006431820208130620                             NaN                    NaN
# 50006440320208130620                             NaN                    NaN
#
#                       codigoAssunto  codigoPaiNacional descricao
# dadosBasicos.numero
# 50006423320208130620            NaN                NaN       NaN
# 50006423320208130620            NaN                NaN       NaN
# 50006431820208130620            NaN                NaN       NaN
# 50006431820208130620            NaN                NaN       NaN
# 50006440320208130620            NaN                NaN       NaN

# %% [markdown]
# # Criando pares de transições entre movimentos dos processos

# %% [markdown]
# ## Duração dos movimentos de cada processo

# %%
# %%time
# Duração dos movimentos de cada processo
df_moves.sort_values(['dadosBasicos.numero', 'dataHora'], inplace=True)
df_moves['duracao_movimento'] = df_moves.groupby(['dadosBasicos.numero'])['dataHora'].apply(lambda x: x - x.shift())
df_moves['duracao_movimento'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     224     )
#     225     def apply(self, func, *args, **kwargs):
# --> 226         return super().apply(func, *args, **kwargs)
#     227
#     228     @doc(
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
# --> 894         return self._wrap_applied_output(
#     895             keys, values, not_indexed_same=mutated or self.mutated
#     896         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _wrap_applied_output(self, keys, values, not_indexed_same)
#     465             return result
#     466         elif isinstance(values[0], (Series, DataFrame)):
# --> 467             return self._concat_objects(keys, values, not_indexed_same=not_indexed_same)
#     468         else:
#     469             # GH #6265 #24880
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _concat_objects(self, keys, values, not_indexed_same)
#    1127             # GH 14776, 30667
#    1128             if ax.has_duplicates:
# -> 1129                 indexer, _ = result.index.get_indexer_non_unique(ax.values)
#    1130                 indexer = algorithms.unique1d(indexer)
#    1131                 result = result.take(indexer, axis=self.axis)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer_non_unique(self, target)
#    4691             tgt_values = target._get_engine_target()
#    4692
# -> 4693         indexer, missing = self._engine.get_indexer_non_unique(tgt_values)
#    4694         return ensure_platform_int(indexer), missing
#    4695
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer_non_unique()
#
# <__array_function__ internals> in resize(*args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/numpy/core/fromnumeric.py in resize(a, new_shape)
#    1415         extra = Na - extra
#    1416
# -> 1417     a = concatenate((a,) * n_copies)
#    1418     if extra > 0:
#    1419         a = a[:-extra]
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Transição do movimento (para agrupar)

# %%
# %%time
# Seta campos de identificação para inteiro
# df_moves['movimentoNacional.codigoNacional'] = df_moves['movimentoNacional.codigoNacional'].fillna(-1).astype(int)
# df_moves['orgaoJulgador.codigoOrgao'] = df_moves['orgaoJulgador.codigoOrgao'].fillna(-1).astype(int)

# Ordena tabela e une nome dos nós
df_moves.sort_values(['dadosBasicos.numero', 'dataHora'], inplace=True)
df_moves['transicao_movimento'] = df_moves.groupby(['dadosBasicos.numero'])['movimentoNacional.codigoNacional'].apply(lambda x: x.shift().astype(str) + ' -> ' + x.astype(str))
# Out:
# CPU times: user 33 s, sys: 201 ms, total: 33.2 s
# Wall time: 32.9 s

# %%
df_moves = df_moves.merge(df_base['siglaTribunal'], left_index=True, right_index=True)
df_moves.head()
# Out:
#                     identificadorMovimento  tipoResponsavelMovimento  \
# dadosBasicos.numero
# 34619888190009       1988.009.000003-8_1_1                       NaN
# 34619888190009       1988.009.000003-8_2_2                       NaN
# 34619888190009       1988.009.000003-8_7_3                       NaN
# 34619888190009       1988.009.000003-8_1_5                       NaN
# 34619888190009       1988.009.000003-8_8_4                       NaN
#
#                     complementoNacional idDocumentoVinculado  movimentoLocal  \
# dadosBasicos.numero
# 34619888190009                      NaN                  NaN             NaN
# 34619888190009                      NaN                  NaN             NaN
# 34619888190009                      NaN                  NaN             NaN
# 34619888190009                      NaN                  NaN             NaN
# 34619888190009                      NaN                  NaN             NaN
#
#                      nivelSigilo   dataHora  tipoDecisao  \
# dadosBasicos.numero
# 34619888190009               NaN 2003-11-07          NaN
# 34619888190009               NaN 2003-12-10          NaN
# 34619888190009               NaN 2004-07-09          NaN
# 34619888190009               NaN 2005-03-03          NaN
# 34619888190009               NaN 2005-03-03          NaN
#
#                      movimentoNacional.codigoNacional orgaoJulgador.nomeOrgao  \
# dadosBasicos.numero
# 34619888190009                                   51.0                     NaN
# 34619888190009                                  123.0                     NaN
# 34619888190009                                  861.0                     NaN
# 34619888190009                                   51.0                     NaN
# 34619888190009                                  893.0                     NaN
#
#                      ...  orgaoJulgador.codigoOrgao  orgaoJulgador.instancia  \
# dadosBasicos.numero  ...
# 34619888190009       ...                        NaN                      NaN
# 34619888190009       ...                        NaN                      NaN
# 34619888190009       ...                        NaN                      NaN
# 34619888190009       ...                        NaN                      NaN
# 34619888190009       ...                        NaN                      NaN
#
#                     movimentoNacional  orgaoJulgador  \
# dadosBasicos.numero
# 34619888190009                    NaN            NaN
# 34619888190009                    NaN            NaN
# 34619888190009                    NaN            NaN
# 34619888190009                    NaN            NaN
# 34619888190009                    NaN            NaN
#
#                      movimentoLocal.movimentoLocalPai  \
# dadosBasicos.numero
# 34619888190009                                    NaN
# 34619888190009                                    NaN
# 34619888190009                                    NaN
# 34619888190009                                    NaN
# 34619888190009                                    NaN
#
#                      movimentoLocal.codigoMovimento  \
# dadosBasicos.numero
# 34619888190009                                  NaN
# 34619888190009                                  NaN
# 34619888190009                                  NaN
# 34619888190009                                  NaN
# 34619888190009                                  NaN
#
#                      movimentoLocal.codigoPaiNacional  duracao_movimento  \
# dadosBasicos.numero
# 34619888190009                                    NaN                NaT
# 34619888190009                                    NaN            33 days
# 34619888190009                                    NaN           212 days
# 34619888190009                                    NaN           237 days
# 34619888190009                                    NaN             0 days
#
#                     transicao_movimento siglaTribunal
# dadosBasicos.numero
# 34619888190009              nan -> 51.0          TJRJ
# 34619888190009            51.0 -> 123.0          TJRJ
# 34619888190009           123.0 -> 861.0          TJRJ
# 34619888190009            861.0 -> 51.0          TJRJ
# 34619888190009            51.0 -> 893.0          TJRJ
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Cria pares

# %%
# siglaTribunal,codigoOrgao,C1,C2,C1-descricao,C2-descricao,quant,tempo-min,tempo-max,mediana
df_moves['duracao_movimento_dias'] = df_moves['duracao_movimento'].dt.days
df_pares = df_moves.groupby(
    ['transicao_movimento', 'siglaTribunal', 'orgaoJulgador.codigoOrgao']
)['duracao_movimento_dias'].agg(
    ['count', 'min', 'max', 'median']
)
df_pares.reset_index(inplace=True)
df_pares[['C1', 'C2']] = df_pares['transicao_movimento'].str.split(' -> ', expand=True)
df_pares['C1-descricao'] = df_pares['C1'].astype(float).map(sgt_movimentos['descricao'])
df_pares['C2-descricao'] = df_pares['C2'].astype(float).map(sgt_movimentos['descricao'])
df_pares.head()
# Out:
#   transicao_movimento siglaTribunal  orgaoJulgador.codigoOrgao  count    min  \
# 0    1051.0 -> 1051.0          TJMG                     3668.0      1    0.0
# 1    1051.0 -> 1051.0          TJMG                     3786.0      1  209.0
# 2    1051.0 -> 1051.0          TJMG                     3840.0      1    0.0
# 3    1051.0 -> 1051.0          TJMG                     3867.0      1   15.0
# 4    1051.0 -> 1051.0          TJMG                     3949.0      4   31.0
#
#      max  median      C1      C2      C1-descricao      C2-descricao
# 0    0.0     0.0  1051.0  1051.0  Decurso de Prazo  Decurso de Prazo
# 1  209.0   209.0  1051.0  1051.0  Decurso de Prazo  Decurso de Prazo
# 2    0.0     0.0  1051.0  1051.0  Decurso de Prazo  Decurso de Prazo
# 3   15.0    15.0  1051.0  1051.0  Decurso de Prazo  Decurso de Prazo
# 4   51.0    34.0  1051.0  1051.0  Decurso de Prazo  Decurso de Prazo

# %%
df_pares.shape
# Out:
# (36348, 11)
